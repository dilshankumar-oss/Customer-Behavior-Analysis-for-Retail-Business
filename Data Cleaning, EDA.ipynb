# %%
# importing pandas library
import pandas as pd

# %%
# python package installer
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head(16)
# Out:
#     Customer ID  Age  Gender Item Purchased     Category  \
# 0          2701   22  Female        T-shirt     Clothing
# 1           521   51    Male     Sunglasses  Accessories
# 2          3157   18  Female          Shirt     Clothing
# 3          1687   22    Male         Gloves  Accessories
# 4          2929   40  Female        Jewelry  Accessories
# 5          3583   23  Female         Shorts     Clothing
# 6          1135   62    Male        T-shirt     Clothing
# 7          1411   61    Male            Hat  Accessories
# 8           113   37    Male         Gloves  Accessories
# 9           166   42    Male        Handbag  Accessories
# 10         4568   35   Other          Shoes     Clothing
# 11          947   46    Male           Coat    Outerwear
# 12         4776   64   Other         Laptop  Electronics
# 13         3855   57  Female        T-shirt     Clothing
# 14          481   68    Male         Hoodie     Clothing
# ...

# %%
# Display the last 5 rows of the dataset
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)      Location Size  Color  Season  Review Rating  \
# 5045                   56.0      Arkansas    M  Green  Winter            3.4
# 5046                   53.0          Iowa    M   Gold  Spring            3.4
# 5047                   27.0  North Dakota    M  White  Summer            3.2
# 5048                   52.0      Maryland    L   Gold  Summer            4.6
# 5049                   71.0         Maine    M   Cyan  Summer            3.3
#
#      Subscription Status  Shipping Type Discount Applied  Previous Purchases  \
# ...

# %%
# Check the total number of records (rows) in the dataset
len(df)
# Out:
# 5050

# %%
# Check the dataset's shape (number of rows and columns)
df.shape
# Out:
# (5050, 17)

# %%
# Generate descriptive statistics for all categorical and numerical columns
df.describe(include="all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   5050.000000  5050.000000   5050           5050      5050
# unique          NaN          NaN      3             30         5
# top             NaN          NaN   Male          Shirt  Clothing
# freq            NaN          NaN   3018            320      2130
# mean    2519.570891    44.150495    NaN            NaN       NaN
# std     1470.402964    15.282328    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%     1252.250000    31.000000    NaN            NaN       NaN
# 50%     2499.500000    44.000000    NaN            NaN       NaN
# 75%     3740.750000    57.000000    NaN            NaN       NaN
# max     5099.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# count             4494.000000      5050  4680   5050    5050    4449.000000
# ...

# %%
# Display information about the dataset, including data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5050 non-null   int64
#  1   Age                     5050 non-null   int64
#  2   Gender                  5050 non-null   object
#  3   Item Purchased          5050 non-null   object
#  4   Category                5050 non-null   object
#  5   Purchase Amount (USD)   4494 non-null   float64
#  6   Location                5050 non-null   object
#  7   Size                    4680 non-null   object
#  8   Color                   5050 non-null   object
#  9   Season                  5050 non-null   object
#  10  Review Rating           4449 non-null   float64
#  11  Subscription Status     5050 non-null   object
#  12  Shipping Type           5050 non-null   object
#  13  Discount Applied        5050 non-null   object
# ...

# %%
#checking the null count
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# Data Cleaning

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
df['Item Purchased']
# Out:
# 0          T-shirt
# 1       Sunglasses
# 2            Shirt
# 3           Gloves
# 4          Jewelry
#            ...
# 5045        Hoodie
# 5046      Backpack
# 5047         Skirt
# 5048      Sneakers
# 5049        Blouse
# Name: Item Purchased, Length: 5050, dtype: object

# %%
# View all unique items purchased by customers
df['Item Purchased'].unique()
# Out:
# array(['T-shirt', 'Sunglasses', 'Shirt', 'Gloves', 'Jewelry', 'Shorts',
#        'Hat', 'Handbag', 'Shoes', 'Coat', 'Laptop', 'Hoodie', 'Phone',
#        'Jacket', 'Pants', 'Backpack', 'Socks', 'Jeans', 'Bag', 'Belt',
#        'Watch', 'Headphones', 'Blouse', 'Sandals', 'Skirt', 'Sweater',
#        'Scarf', 'Sneakers', 'Boots', 'Dress'], dtype=object)

# %%
# View all unique categories in the dataset
df['Category'].unique()
# Out:
# array(['Clothing', 'Accessories', 'Outerwear', 'Electronics', 'Footwear'],
#       dtype=object)

# %%
# See which items belong to which categories
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories    [Sunglasses, Gloves, Jewelry, Hat, Handbag, Ph...
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone,...
# Electronics    [Laptop, Phone, Watch, Bag, Shoes, Shirt, Head...
# Footwear                       [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                         [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
# Adjust Pandas display options to show all rows and columns without truncating
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
# Define a dictionary to map items to their correct categories for data cleaning
correct_mapping = {
    # Clothing
    "T-shirt": "Clothing", "Shirt": "Clothing", "Shorts": "Clothing",
    "Hoodie": "Clothing", "Pants": "Clothing", "Socks": "Clothing",
    "Jeans": "Clothing", "Blouse": "Clothing", "Skirt": "Clothing",
    "Sweater": "Clothing", "Dress": "Clothing",

    # Accessories
    "Sunglasses": "Accessories", "Gloves": "Accessories",
    "Jewelry": "Accessories", "Hat": "Accessories",
    "Handbag": "Accessories", "Backpack": "Accessories",
    "Belt": "Accessories", "Scarf": "Accessories",
    "Bag": "Accessories",

    # Electronics
    "Laptop": "Electronics", "Phone": "Electronics",
    "Headphones": "Electronics", "Watch": "Electronics",

    # Footwear
    "Shoes": "Footwear", "Sandals": "Footwear",
    "Sneakers": "Footwear", "Boots": "Footwear",

    # Outerwear
    "Coat": "Outerwear", "Jacket": "Outerwear"
}

# %%
# Define a dictionary to map items to their correct categories for data cleaning
correct_mapping
# Out:
# {'T-shirt': 'Clothing',
#  'Shirt': 'Clothing',
#  'Shorts': 'Clothing',
#  'Hoodie': 'Clothing',
#  'Pants': 'Clothing',
#  'Socks': 'Clothing',
#  'Jeans': 'Clothing',
#  'Blouse': 'Clothing',
#  'Skirt': 'Clothing',
#  'Sweater': 'Clothing',
#  'Dress': 'Clothing',
#  'Sunglasses': 'Accessories',
#  'Gloves': 'Accessories',
#  'Jewelry': 'Accessories',
#  'Hat': 'Accessories',
#  'Handbag': 'Accessories',
#  'Backpack': 'Accessories',
#  'Belt': 'Accessories',
#  'Scarf': 'Accessories',
#  'Bag': 'Accessories',
#  'Laptop': 'Electronics',
#  'Phone': 'Electronics',
#  'Headphones': 'Electronics',
#  'Watch': 'Electronics',
#  'Shoes': 'Footwear',
#  'Sandals': 'Footwear',
#  'Sneakers': 'Footwear',
#  'Boots': 'Footwear',
#  'Coat': 'Outerwear',
#  'Jacket': 'Outerwear'}

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
# See which items belong to which categories
df['Category']=df['Item Purchased'].map(correct_mapping)
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# Treating the null values

# %%
df['Size'].unique()
# Out:
# array(['XL', 'M', 'L', 'S', nan], dtype=object)

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
# Check the unique sizes available for each category to identify mismatches
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.groupby('Item Purchased')['Size'].unique()
# Out:
# Item Purchased
# Backpack           [M, S, L, XL]
# Bag           [M, L, nan, XL, S]
# Belt               [M, S, XL, L]
# Blouse             [M, L, S, XL]
# Boots              [L, M, XL, S]
# Coat               [XL, M, S, L]
# Dress              [XL, M, L, S]
# Gloves             [L, M, S, XL]
# Handbag            [S, XL, M, L]
# Hat                [M, L, S, XL]
# Headphones    [S, M, nan, L, XL]
# Hoodie             [M, L, S, XL]
# Jacket             [L, S, M, XL]
# Jeans              [L, M, XL, S]
# Jewelry            [L, XL, M, S]
# Laptop        [nan, M, S, XL, L]
# Pants              [L, M, XL, S]
# Phone         [nan, L, S, M, XL]
# Sandals            [M, S, L, XL]
# Scarf              [M, L, S, XL]
# Shirt         [M, XL, L, S, nan]
# Shoes         [M, L, nan, XL, S]
# Shorts             [S, M, L, XL]
# Skirt              [S, L, M, XL]
# Sneakers           [S, M, L, XL]
# Socks              [M, XL, L, S]
# Sunglasses         [M, L, S, XL]
# Sweater            [M, S, L, XL]
# ...

# %%
# See which items belong to which categories
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
# Check the unique sizes available for each category to identify mismatches
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in the Electronics category
df.loc[df['Category']=='Electronics','Size']="Not Applicable"

# %%
# Check the unique sizes available for each category to identify mismatches
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in the Accessories category
df.loc[df['Category']=='Accessories','Size']="Free Size"
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in the Footwear category
df.loc[df['Category']=='Footwear','Size']="Not Available"
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear          [Not Available]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in the Clothing category
df.loc[(df["Category"]=="Clothing") & (df["Size"].isnull()), "Size"] = df[df["Category"]=="Clothing"]["Size"].mode()[0]
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories         [Free Size]
# Clothing          [XL, M, S, L]
# Electronics    [Not Applicable]
# Footwear        [Not Available]
# Outerwear         [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# Review Rating

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# 4                   80.0         Alabama  Free Size  Yellow  Spring
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0            3.2                  No        Standard               No
# 1            3.9                 Yes   Free Shipping              Yes
# ...

# %%
# mean of review ratings
df['Review Rating'].mean()
# Out:
# np.float64(3.668195100022477)

# %%
# median of review ratings
df['Review Rating'].median()
# Out:
# np.float64(3.7)

# %%
# mode of review ratings
df['Review Rating'].mode()
# Out:
# 0    4.0
# Name: Review Rating, dtype: float64

# %%
df.groupby("Item Purchased")['Review Rating'].mean()
# Out:
# Item Purchased
# Backpack      3.758333
# Bag           3.168539
# Belt          3.762963
# Blouse        3.677647
# Boots         3.813194
# Coat          3.721875
# Dress         3.750000
# Gloves        3.862774
# Handbag       3.771975
# Hat           3.796753
# Headphones    3.075949
# Hoodie        3.716779
# Jacket        3.761446
# Jeans         3.651969
# Jewelry       3.761850
# Laptop        3.191176
# Pants         3.720833
# Phone         2.939024
# Sandals       3.837037
# Scarf         3.702564
# Shirt         3.427273
# Shoes         3.546154
# Shorts        3.722981
# Skirt         3.779747
# Sneakers      3.757931
# Socks         3.755063
# Sunglasses    3.745679
# Sweater       3.768712
# T-shirt       3.790541
# Watch         3.100000
# Name: Review Rating, dtype: float64

# %%
#Filling null values of Review Ratings with the mean of each Item Purchased
df['Review Rating']=df['Review Rating'].fillna(df.groupby('Item Purchased')['Review Rating'] .transform ('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.head(10)
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
# 5         3583   23  Female         Shorts     Clothing
# 6         1135   62    Male        T-shirt     Clothing
# 7         1411   61    Male            Hat  Accessories
# 8          113   37    Male         Gloves  Accessories
# 9          166   42    Male        Handbag  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# ...

# %%
df['Review Rating']=df['Review Rating'].round(2)
df.head(10)
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
# 5         3583   23  Female         Shorts     Clothing
# 6         1135   62    Male        T-shirt     Clothing
# 7         1411   61    Male            Hat  Accessories
# 8          113   37    Male         Gloves  Accessories
# 9          166   42    Male        Handbag  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# ...

# %% [markdown]
# Previous Purchases

# %%
# Filling Previous Purchases with Zero(0)
df['Previous Purchases']=df['Previous Purchases'].fillna(0)
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# Purchase Amount (USD)

# %%
df.groupby("Item Purchased")['Purchase Amount (USD)'].mean()
# Out:
# Item Purchased
# Backpack       60.111111
# Bag           735.773625
# Belt           59.993902
# Blouse         60.802326
# Boots          62.616438
# Coat           57.851852
# Dress          62.168675
# Gloves         60.550000
# Handbag        57.987261
# Hat            60.787097
# Headphones    831.344565
# Hoodie         58.059603
# Jacket         56.777108
# Jeans          60.456693
# Jewelry        59.011494
# Laptop        805.502027
# Pants          59.005848
# Phone         734.477349
# Sandals        57.527607
# Scarf          61.157233
# Shirt         279.935608
# Shoes         276.343790
# Shorts         60.073620
# Skirt          59.723270
# Sneakers       59.551724
# Socks          58.188679
# Sunglasses     59.975610
# Sweater        57.638554
# T-shirt        63.093333
# Watch         685.231471
# Name: Purchase Amount (USD), dtype: float64

# %%
#Filling null values of Purchase Amount (USD) with the mean of each Item Purchased
df['Purchase Amount (USD)']=df['Purchase Amount (USD)'].fillna(df.groupby('Item Purchased')['Purchase Amount (USD)'] .transform ('mean'))
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# Checking Duplicates

# %%
# Count the total number of duplicate rows in the dataset
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
# Display the actual duplicate records
df[df.duplicated()]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 886          2834   43  Female          Jeans     Clothing
# 1402         1621   25    Male            Hat  Accessories
# 1509          974   60    Male         Jacket    Outerwear
# 1600         2135   55    Male        Sandals     Footwear
# 1665         1846   51    Male        Sandals     Footwear
# 1797         3639   40  Female       Backpack  Accessories
# 1870         3456   49  Female        T-shirt     Clothing
# 2033         1812   42    Male           Belt  Accessories
# 2113         3040   59  Female         Blouse     Clothing
# 2226         1371   27    Male          Scarf  Accessories
# 2358         2977   30  Female           Coat    Outerwear
# 2447         2678   45  Female         Shorts     Clothing
# 2630          992   20    Male         Shorts     Clothing
# 2642         1566   58    Male     Sunglasses  Accessories
# 2739         2227   22    Male          Shirt     Clothing
# ...

# %%
# Inspect a specific customer ID to verify the duplication
df[df['Customer ID']==974]
# Out:
#       Customer ID  Age Gender Item Purchased   Category  \
# 483           974   60   Male         Jacket  Outerwear
# 1509          974   60   Male         Jacket  Outerwear
#
#       Purchase Amount (USD)  Location Size Color Season  Review Rating  \
# 483                    75.0  Colorado    M  Teal   Fall            3.5
# 1509                   75.0  Colorado    M  Teal   Fall            3.5
#
#      Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 483                  Yes  2-Day Shipping              Yes                30.0
# 1509                 Yes  2-Day Shipping              Yes                30.0
#
#      Payment Method Frequency of Purchases
# 483   Bank Transfer              Quarterly
# 1509  Bank Transfer              Quarterly

# %%
# Check the total number of records (rows) in the dataset
len(df)
# Out:
# 5050

# %%
# Deleting duplicate records
df=df.drop_duplicates(subset=['Customer ID'],keep='first')

# %%
# Check the total number of records (rows) in the dataset
len(df)
# Out:
# 5000

# %%
# Count the total number of duplicate rows in the dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check the count of non-null values for each column after cleaning
df.count()
# Out:
# Customer ID               5000
# Age                       5000
# Gender                    5000
# Item Purchased            5000
# Category                  5000
# Purchase Amount (USD)     5000
# Location                  5000
# Size                      5000
# Color                     5000
# Season                    5000
# Review Rating             5000
# Subscription Status       5000
# Shipping Type             5000
# Discount Applied          5000
# Previous Purchases        4452
# Payment Method            5000
# Frequency of Purchases    5000
# dtype: int64

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# 4                   80.0         Alabama  Free Size  Yellow  Spring
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0            3.2                  No        Standard               No
# 1            3.9                 Yes   Free Shipping              Yes
# ...

# %%
# Display the updated column names to verify changes
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# Renaming the Headers

# %%
# Standardize column names by replacing spaces with underscores
df.columns=df.columns.str.replace(" ","_")
df.columns=df.columns.str.lower()

# %%
# Display the updated column names to verify changes
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
#replacing purchase_amount_(usd) to purchase_amount
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})

# %%
# Display the updated column names to verify changes
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
df.head()
# Out:
#    customer_id  age  gender item_purchased     category  purchase_amount  \
# 0         2701   22  Female        T-shirt     Clothing             68.0
# 1          521   51    Male     Sunglasses  Accessories             84.0
# 2         3157   18  Female          Shirt     Clothing             50.0
# 3         1687   22    Male         Gloves  Accessories             75.0
# 4         2929   40  Female        Jewelry  Accessories             80.0
#
#          location       size   color  season  review_rating  \
# 0      California         XL   Olive  Winter            3.2
# 1  South Carolina  Free Size   White  Spring            3.9
# 2         Montana          M   Black  Winter            3.1
# 3        Illinois  Free Size     Red    Fall            4.2
# 4         Alabama  Free Size  Yellow  Spring            3.6
#
#   subscription_status   shipping_type discount_applied  previous_purchases  \
# 0                  No        Standard               No                36.0
# ...

# %% [markdown]
# ### Connecting to MySQL Server (XAMPP)

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 10.1 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pymysql]
#    ---------------------------------------- 0/3 [pymysql]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
from sqlalchemy import create_engine

# 1. Define XAMPP credentials
username = 'root'
password = 'Saurabh#123'
host = 'localhost'
port = 3306
database = 'data_analysis_project'  # Type the exact DB name you created in phpMyAdmin

# %%
# 2. Create the database connection engine
engine_path = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(engine_path)

# %%
# 3. Upload the data
# Replace 'df' with your actual DataFrame variable name
# 'customer_behaviour_analysis' is what you want to name the table in MySQL
df.to_sql(name='customer_behaviour_analysis', con=engine, if_exists='replace', index=False)

print("Data uploaded to MySQL successfully!")
# Out:
# Data uploaded to MySQL successfully!
